# %%
import sys
sys.path.append('../')
from utility.file_utility import FileUtility
import pandas as pd
import numpy as np

# %%
def get_cv_res(filename):
    [label_set, conf, best_score_, best_estimator_,cv_results_, best_params_, pred]=FileUtility.load_obj(filename)
    res=dict()
    idx=np.argmax(cv_results_['mean_test_f1_macro'])
    res['f1_macro*']=np.round(cv_results_['mean_test_f1_macro'][idx],2)
    res['f1_macro']=str(np.round(cv_results_['mean_test_f1_macro'][idx],2))+ ' $\pm$ ' + str(np.round(cv_results_['std_test_f1_macro'][idx],2))
    res['f1_micro']=str(np.round(cv_results_['mean_test_f1_micro'][idx],2))+ ' $\pm$ ' + str(np.round(cv_results_['std_test_f1_micro'][idx],2))
    res['precision_micro']=str(np.round(cv_results_['mean_test_precision_micro'][idx],2))+ ' $\pm$ ' + str(np.round(cv_results_['std_test_precision_micro'][idx],2))
    res['precision_macro']=str(np.round(cv_results_['mean_test_precision_macro'][idx],2))+ ' $\pm$ ' + str(np.round(cv_results_['std_test_precision_macro'][idx],2))
    res['recall_micro']=str(np.round(cv_results_['mean_test_recall_micro'][idx],2))+ ' $\pm$ ' + str(np.round(cv_results_['std_test_recall_micro'][idx],2))
    res['recall_macro']=str(np.round(cv_results_['mean_test_recall_macro'][idx],2))+ ' $\pm$ ' + str(np.round(cv_results_['std_test_recall_macro'][idx],2))
    res['accuracy']=str(np.round(cv_results_['mean_test_accuracy'][idx],2))+ ' $\pm$ ' + str(np.round(cv_results_['std_test_accuracy'][idx],2))
    res['tnr']=str(np.round(cv_results_['mean_test_tnr'][idx],2))+ ' $\pm$ ' + str(np.round(cv_results_['std_test_tnr'][idx],2))
    res['scores_p_0']=str(np.round(cv_results_['mean_test_scores_p_0'][idx],2))+ ' $\pm$ ' + str(np.round(cv_results_['std_test_scores_p_0'][idx],2))
    res['scores_r_0']=str(np.round(cv_results_['mean_test_scores_r_0'][idx],2))+ ' $\pm$ ' + str(np.round(cv_results_['std_test_scores_r_0'][idx],2))
    res['scores_f_1_0']=str(np.round(cv_results_['mean_test_scores_f_1_0'][idx],2))+ ' $\pm$ ' + str(np.round(cv_results_['std_test_scores_f_1_0'][idx],2))
    res['scores_f_1_1']=str(np.round(cv_results_['mean_test_scores_f_1_1'][idx],2))+ ' $\pm$ ' + str(np.round(cv_results_['std_test_scores_f_1_1'][idx],2))
    res['scores_p_1']=str(np.round(cv_results_['mean_test_scores_p_1'][idx],2))+ ' $\pm$ ' + str(np.round(cv_results_['std_test_scores_p_1'][idx],2))
    res['scores_r_1']=str(np.round(cv_results_['mean_test_scores_r_1'][idx],2))+ ' $\pm$ ' + str(np.round(cv_results_['std_test_scores_r_1'][idx],2)) 
    res['file']=filename
    return res

# %%
[label_set, conf, best_score_, best_estimator_,cv_results_, best_params_, pred]=FileUtility.load_obj('../../amr_results/classifications_standard/Ceftazidimgenexp_RF.pickle')
# Out:
# /mounts/Users/student/asgari/.local/lib/python3.4/site-packages/sklearn/base.py:311: UserWarning: Trying to unpickle estimator DecisionTreeClassifier from version 0.19.0 when using version 0.19.1. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# /mounts/Users/student/asgari/.local/lib/python3.4/site-packages/sklearn/base.py:311: UserWarning: Trying to unpickle estimator RandomForestClassifier from version 0.19.0 when using version 0.19.1. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)

# %%
cv_results_
# Out:
# {'mean_fit_time': array([  1.44015441,   2.92394617,   9.25090656,  30.66007507]),
#  'mean_score_time': array([  5.52640755,  13.66874139,  48.24292259,  77.83159559]),
#  'mean_test_accuracy': array([ 0.72155689,  0.71856287,  0.73053892,  0.70658683]),
#  'mean_test_f1_macro': array([ 0.71781388,  0.71412486,  0.72524976,  0.70162045]),
#  'mean_test_f1_micro': array([ 0.72155689,  0.71856287,  0.73053892,  0.70658683]),
#  'mean_test_precision_macro': array([ 0.73014201,  0.72742352,  0.73520528,  0.71252415]),
#  'mean_test_precision_micro': array([ 0.72155689,  0.71856287,  0.73053892,  0.70658683]),
#  'mean_test_recall_macro': array([ 0.73002355,  0.72579538,  0.73419287,  0.71209571]),
#  'mean_test_recall_micro': array([ 0.72155689,  0.71856287,  0.73053892,  0.70658683]),
#  'mean_test_scores_f_1_0': array([ 0.73140399,  0.73071898,  0.74212459,  0.72155225]),
#  'mean_test_scores_f_1_1': array([ 0.70422377,  0.69753074,  0.70837494,  0.68168864]),
#  'mean_test_scores_p_0': array([ 0.71699382,  0.71071388,  0.72034227,  0.69631132]),
#  'mean_test_scores_p_1': array([ 0.74329021,  0.74413316,  0.75006828,  0.72873697]),
#  'mean_test_scores_r_0': array([ 0.76715881,  0.77203834,  0.78073523,  0.76605032]),
#  'mean_test_scores_r_1': array([ 0.69288828,  0.67955242,  0.68765051,  0.65814111]),
#  'mean_test_tnr': array([ 0.76715881,  0.77203834,  0.78073523,  0.76605032]),
#  'mean_train_accuracy': array([ 1.,  1.,  1.,  1.]),
#  'mean_train_f1_macro': array([ 1.,  1.,  1.,  1.]),
#  'mean_train_f1_micro': array([ 1.,  1.,  1.,  1.]),
#  'mean_train_precision_macro': array([ 1.,  1.,  1.,  1.]),
#  'mean_train_precision_micro': array([ 1.,  1.,  1.,  1.]),
#  'mean_train_recall_macro': array([ 1.,  1.,  1.,  1.]),
#  'mean_train_recall_micro': array([ 1.,  1.,  1.,  1.]),
#  'mean_train_scores_f_1_0': array([ 1.,  1.,  1.,  1.]),
#  'mean_train_scores_f_1_1': array([ 1.,  1.,  1.,  1.]),
#  'mean_train_scores_p_0': array([ 1.,  1.,  1.,  1.]),
#  'mean_train_scores_p_1': array([ 1.,  1.,  1.,  1.]),
#  'mean_train_scores_r_0': array([ 1.,  1.,  1.,  1.]),
#  'mean_train_scores_r_1': array([ 1.,  1.,  1.,  1.]),
#  'mean_train_tnr': array([ 1.,  1.,  1.,  1.]),
#  'param_criterion': masked_array(data = ['entropy' 'entropy' 'entropy' 'entropy'],
#               mask = [False False False False],
#         fill_value = ?),
#  'param_max_features': masked_array(data = ['sqrt' 'sqrt' 'sqrt' 'sqrt'],
#               mask = [False False False False],
#         fill_value = ?),
#  'param_min_samples_leaf': masked_array(data = [1 1 1 1],
#               mask = [False False False False],
#         fill_value = ?),
#  'param_min_samples_split': masked_array(data = [5 5 5 5],
#               mask = [False False False False],
#         fill_value = ?),
#  'param_n_estimators': masked_array(data = [100 200 500 1000],
#               mask = [False False False False],
#         fill_value = ?),
#  'params': [{'criterion': 'entropy',
#    'max_features': 'sqrt',
#    'min_samples_leaf': 1,
#    'min_samples_split': 5,
#    'n_estimators': 100},
#   {'criterion': 'entropy',
#    'max_features': 'sqrt',
#    'min_samples_leaf': 1,
#    'min_samples_split': 5,
#    'n_estimators': 200},
#   {'criterion': 'entropy',
#    'max_features': 'sqrt',
#    'min_samples_leaf': 1,
#    'min_samples_split': 5,
#    'n_estimators': 500},
#   {'criterion': 'entropy',
#    'max_features': 'sqrt',
#    'min_samples_leaf': 1,
#    'min_samples_split': 5,
#    'n_estimators': 1000}],
#  'rank_test_accuracy': array([2, 3, 1, 4], dtype=int32),
#  'rank_test_f1_macro': array([2, 3, 1, 4], dtype=int32),
#  'rank_test_f1_micro': array([2, 3, 1, 4], dtype=int32),
#  'rank_test_precision_macro': array([2, 3, 1, 4], dtype=int32),
#  'rank_test_precision_micro': array([2, 3, 1, 4], dtype=int32),
#  'rank_test_recall_macro': array([2, 3, 1, 4], dtype=int32),
#  'rank_test_recall_micro': array([2, 3, 1, 4], dtype=int32),
#  'rank_test_scores_f_1_0': array([2, 3, 1, 4], dtype=int32),
#  'rank_test_scores_f_1_1': array([2, 3, 1, 4], dtype=int32),
#  'rank_test_scores_p_0': array([2, 3, 1, 4], dtype=int32),
#  'rank_test_scores_p_1': array([3, 2, 1, 4], dtype=int32),
#  'rank_test_scores_r_0': array([3, 2, 1, 4], dtype=int32),
#  'rank_test_scores_r_1': array([1, 3, 2, 4], dtype=int32),
#  'rank_test_tnr': array([3, 2, 1, 4], dtype=int32),
#  'split0_test_accuracy': array([ 0.67647059,  0.67647059,  0.67647059,  0.67647059]),
#  'split0_test_f1_macro': array([ 0.67619048,  0.67619048,  0.67619048,  0.67619048]),
#  'split0_test_f1_micro': array([ 0.67647059,  0.67647059,  0.67647059,  0.67647059]),
#  'split0_test_precision_macro': array([ 0.67647059,  0.68245614,  0.68245614,  0.68245614]),
#  'split0_test_precision_micro': array([ 0.67647059,  0.67647059,  0.67647059,  0.67647059]),
#  'split0_test_recall_macro': array([ 0.67708333,  0.68055556,  0.68055556,  0.68055556]),
#  'split0_test_recall_micro': array([ 0.67647059,  0.67647059,  0.67647059,  0.67647059]),
#  'split0_test_scores_f_1_0': array([ 0.66666667,  0.68571429,  0.68571429,  0.68571429]),
#  'split0_test_scores_f_1_1': array([ 0.68571429,  0.66666667,  0.66666667,  0.66666667]),
#  'split0_test_scores_p_0': array([ 0.64705882,  0.63157895,  0.63157895,  0.63157895]),
#  'split0_test_scores_p_1': array([ 0.70588235,  0.73333333,  0.73333333,  0.73333333]),
#  'split0_test_scores_r_0': array([ 0.6875,  0.75  ,  0.75  ,  0.75  ]),
#  'split0_test_scores_r_1': array([ 0.66666667,  0.61111111,  0.61111111,  0.61111111]),
#  'split0_test_tnr': array([ 0.6875,  0.75  ,  0.75  ,  0.75  ]),
#  'split0_train_accuracy': array([ 1.,  1.,  1.,  1.]),
#  'split0_train_f1_macro': array([ 1.,  1.,  1.,  1.]),
#  'split0_train_f1_micro': array([ 1.,  1.,  1.,  1.]),
#  'split0_train_precision_macro': array([ 1.,  1.,  1.,  1.]),
#  'split0_train_precision_micro': array([ 1.,  1.,  1.,  1.]),
#  'split0_train_recall_macro': array([ 1.,  1.,  1.,  1.]),
#  'split0_train_recall_micro': array([ 1.,  1.,  1.,  1.]),
#  'split0_train_scores_f_1_0': array([ 1.,  1.,  1.,  1.]),
#  'split0_train_scores_f_1_1': array([ 1.,  1.,  1.,  1.]),
#  'split0_train_scores_p_0': array([ 1.,  1.,  1.,  1.]),
#  'split0_train_scores_p_1': array([ 1.,  1.,  1.,  1.]),
#  'split0_train_scores_r_0': array([ 1.,  1.,  1.,  1.]),
#  'split0_train_scores_r_1': array([ 1.,  1.,  1.,  1.]),
#  'split0_train_tnr': array([ 1.,  1.,  1.,  1.]),
#  'split1_test_accuracy': array([ 0.73529412,  0.73529412,  0.70588235,  0.70588235]),
#  'split1_test_f1_macro': array([ 0.72944297,  0.72944297,  0.70175439,  0.70175439]),
#  'split1_test_f1_micro': array([ 0.73529412,  0.73529412,  0.70588235,  0.70588235]),
#  'split1_test_precision_macro': array([ 0.75757576,  0.75757576,  0.71794872,  0.71794872]),
#  'split1_test_precision_micro': array([ 0.73529412,  0.73529412,  0.70588235,  0.70588235]),
#  'split1_test_recall_macro': array([ 0.73529412,  0.73529412,  0.70588235,  0.70588235]),
#  'split1_test_recall_micro': array([ 0.73529412,  0.73529412,  0.70588235,  0.70588235]),
#  'split1_test_scores_f_1_0': array([ 0.76923077,  0.76923077,  0.73684211,  0.73684211]),
#  'split1_test_scores_f_1_1': array([ 0.68965517,  0.68965517,  0.66666667,  0.66666667]),
#  'split1_test_scores_p_0': array([ 0.68181818,  0.68181818,  0.66666667,  0.66666667]),
#  'split1_test_scores_p_1': array([ 0.83333333,  0.83333333,  0.76923077,  0.76923077]),
#  'split1_test_scores_r_0': array([ 0.88235294,  0.88235294,  0.82352941,  0.82352941]),
#  'split1_test_scores_r_1': array([ 0.58823529,  0.58823529,  0.58823529,  0.58823529]),
#  'split1_test_tnr': array([ 0.88235294,  0.88235294,  0.82352941,  0.82352941]),
#  'split1_train_accuracy': array([ 1.,  1.,  1.,  1.]),
#  'split1_train_f1_macro': array([ 1.,  1.,  1.,  1.]),
#  'split1_train_f1_micro': array([ 1.,  1.,  1.,  1.]),
#  'split1_train_precision_macro': array([ 1.,  1.,  1.,  1.]),
#  'split1_train_precision_micro': array([ 1.,  1.,  1.,  1.]),
#  'split1_train_recall_macro': array([ 1.,  1.,  1.,  1.]),
#  'split1_train_recall_micro': array([ 1.,  1.,  1.,  1.]),
#  'split1_train_scores_f_1_0': array([ 1.,  1.,  1.,  1.]),
#  'split1_train_scores_f_1_1': array([ 1.,  1.,  1.,  1.]),
#  'split1_train_scores_p_0': array([ 1.,  1.,  1.,  1.]),
#  'split1_train_scores_p_1': array([ 1.,  1.,  1.,  1.]),
#  'split1_train_scores_r_0': array([ 1.,  1.,  1.,  1.]),
#  'split1_train_scores_r_1': array([ 1.,  1.,  1.,  1.]),
#  'split1_train_tnr': array([ 1.,  1.,  1.,  1.]),
#  'split2_test_accuracy': array([ 0.67647059,  0.70588235,  0.67647059,  0.67647059]),
#  'split2_test_f1_macro': array([ 0.67619048,  0.70588235,  0.67619048,  0.67619048]),
#  'split2_test_f1_micro': array([ 0.67647059,  0.70588235,  0.67647059,  0.67647059]),
#  'split2_test_precision_macro': array([ 0.69285714,  0.71578947,  0.68055556,  0.69285714]),
#  'split2_test_precision_micro': array([ 0.67647059,  0.70588235,  0.67647059,  0.67647059]),
#  'split2_test_recall_macro': array([ 0.68947368,  0.71578947,  0.68245614,  0.68947368]),
#  'split2_test_recall_micro': array([ 0.67647059,  0.70588235,  0.67647059,  0.67647059]),
#  'split2_test_scores_f_1_0': array([ 0.68571429,  0.70588235,  0.66666667,  0.68571429]),
#  'split2_test_scores_f_1_1': array([ 0.66666667,  0.70588235,  0.68571429,  0.66666667]),
#  'split2_test_scores_p_0': array([ 0.6       ,  0.63157895,  0.61111111,  0.6       ]),
#  'split2_test_scores_p_1': array([ 0.78571429,  0.8       ,  0.75      ,  0.78571429]),
#  'split2_test_scores_r_0': array([ 0.8       ,  0.8       ,  0.73333333,  0.8       ]),
#  'split2_test_scores_r_1': array([ 0.57894737,  0.63157895,  0.63157895,  0.57894737]),
#  'split2_test_tnr': array([ 0.8       ,  0.8       ,  0.73333333,  0.8       ]),
#  'split2_train_accuracy': array([ 1.,  1.,  1.,  1.]),
#  'split2_train_f1_macro': array([ 1.,  1.,  1.,  1.]),
#  'split2_train_f1_micro': array([ 1.,  1.,  1.,  1.]),
#  'split2_train_precision_macro': array([ 1.,  1.,  1.,  1.]),
#  'split2_train_precision_micro': array([ 1.,  1.,  1.,  1.]),
#  'split2_train_recall_macro': array([ 1.,  1.,  1.,  1.]),
#  'split2_train_recall_micro': array([ 1.,  1.,  1.,  1.]),
#  'split2_train_scores_f_1_0': array([ 1.,  1.,  1.,  1.]),
#  'split2_train_scores_f_1_1': array([ 1.,  1.,  1.,  1.]),
#  'split2_train_scores_p_0': array([ 1.,  1.,  1.,  1.]),
#  'split2_train_scores_p_1': array([ 1.,  1.,  1.,  1.]),
#  'split2_train_scores_r_0': array([ 1.,  1.,  1.,  1.]),
#  'split2_train_scores_r_1': array([ 1.,  1.,  1.,  1.]),
#  'split2_train_tnr': array([ 1.,  1.,  1.,  1.]),
#  'split3_test_accuracy': array([ 0.70588235,  0.70588235,  0.73529412,  0.67647059]),
#  'split3_test_f1_macro': array([ 0.69642857,  0.70175439,  0.72357724,  0.66931919]),
#  'split3_test_f1_micro': array([ 0.70588235,  0.70588235,  0.73529412,  0.67647059]),
#  'split3_test_precision_macro': array([ 0.69642857,  0.70138889,  0.72710623,  0.66842105]),
#  'split3_test_precision_micro': array([ 0.70588235,  0.70588235,  0.73529412,  0.67647059]),
#  'split3_test_recall_macro': array([ 0.69642857,  0.70714286,  0.72142857,  0.67142857]),
#  'split3_test_recall_micro': array([ 0.70588235,  0.70588235,  0.73529412,  0.67647059]),
#  'split3_test_scores_f_1_0': array([ 0.75      ,  0.73684211,  0.7804878 ,  0.71794872]),
#  'split3_test_scores_f_1_1': array([ 0.64285714,  0.66666667,  0.66666667,  0.62068966]),
#  'split3_test_scores_p_0': array([ 0.75      ,  0.77777778,  0.76190476,  0.73684211]),
#  'split3_test_scores_p_1': array([ 0.64285714,  0.625     ,  0.69230769,  0.6       ]),
#  'split3_test_scores_r_0': array([ 0.75,  0.7 ,  0.8 ,  0.7 ]),
#  'split3_test_scores_r_1': array([ 0.64285714,  0.71428571,  0.64285714,  0.64285714]),
#  'split3_test_tnr': array([ 0.75,  0.7 ,  0.8 ,  0.7 ]),
#  'split3_train_accuracy': array([ 1.,  1.,  1.,  1.]),
#  'split3_train_f1_macro': array([ 1.,  1.,  1.,  1.]),
#  'split3_train_f1_micro': array([ 1.,  1.,  1.,  1.]),
#  'split3_train_precision_macro': array([ 1.,  1.,  1.,  1.]),
#  'split3_train_precision_micro': array([ 1.,  1.,  1.,  1.]),
#  'split3_train_recall_macro': array([ 1.,  1.,  1.,  1.]),
#  'split3_train_recall_micro': array([ 1.,  1.,  1.,  1.]),
#  'split3_train_scores_f_1_0': array([ 1.,  1.,  1.,  1.]),
#  'split3_train_scores_f_1_1': array([ 1.,  1.,  1.,  1.]),
#  'split3_train_scores_p_0': array([ 1.,  1.,  1.,  1.]),
#  'split3_train_scores_p_1': array([ 1.,  1.,  1.,  1.]),
#  'split3_train_scores_r_0': array([ 1.,  1.,  1.,  1.]),
#  'split3_train_scores_r_1': array([ 1.,  1.,  1.,  1.]),
#  'split3_train_tnr': array([ 1.,  1.,  1.,  1.]),
#  'split4_test_accuracy': array([ 0.75757576,  0.6969697 ,  0.75757576,  0.66666667]),
#  'split4_test_f1_macro': array([ 0.75555556,  0.69444444,  0.75555556,  0.66543779]),
#  'split4_test_f1_micro': array([ 0.75757576,  0.6969697 ,  0.75757576,  0.66666667]),
#  'split4_test_precision_macro': array([ 0.75555556,  0.69444444,  0.75555556,  0.66544118]),
#  'split4_test_precision_micro': array([ 0.75757576,  0.6969697 ,  0.75757576,  0.66666667]),
#  'split4_test_recall_macro': array([ 0.75555556,  0.69444444,  0.75555556,  0.66666667]),
#  'split4_test_recall_micro': array([ 0.75757576,  0.6969697 ,  0.75757576,  0.66666667]),
#  'split4_test_scores_f_1_0': array([ 0.73333333,  0.66666667,  0.73333333,  0.64516129]),
#  'split4_test_scores_f_1_1': array([ 0.77777778,  0.72222222,  0.77777778,  0.68571429]),
#  'split4_test_scores_p_0': array([ 0.73333333,  0.66666667,  0.73333333,  0.625     ]),
#  'split4_test_scores_p_1': array([ 0.77777778,  0.72222222,  0.77777778,  0.70588235]),
#  'split4_test_scores_r_0': array([ 0.73333333,  0.66666667,  0.73333333,  0.66666667]),
#  'split4_test_scores_r_1': array([ 0.77777778,  0.72222222,  0.77777778,  0.66666667]),
#  'split4_test_tnr': array([ 0.73333333,  0.66666667,  0.73333333,  0.66666667]),
#  'split4_train_accuracy': array([ 1.,  1.,  1.,  1.]),
#  'split4_train_f1_macro': array([ 1.,  1.,  1.,  1.]),
#  'split4_train_f1_micro': array([ 1.,  1.,  1.,  1.]),
#  'split4_train_precision_macro': array([ 1.,  1.,  1.,  1.]),
#  'split4_train_precision_micro': array([ 1.,  1.,  1.,  1.]),
#  'split4_train_recall_macro': array([ 1.,  1.,  1.,  1.]),
#  'split4_train_recall_micro': array([ 1.,  1.,  1.,  1.]),
#  'split4_train_scores_f_1_0': array([ 1.,  1.,  1.,  1.]),
#  'split4_train_scores_f_1_1': array([ 1.,  1.,  1.,  1.]),
#  'split4_train_scores_p_0': array([ 1.,  1.,  1.,  1.]),
#  'split4_train_scores_p_1': array([ 1.,  1.,  1.,  1.]),
#  'split4_train_scores_r_0': array([ 1.,  1.,  1.,  1.]),
#  'split4_train_scores_r_1': array([ 1.,  1.,  1.,  1.]),
#  'split4_train_tnr': array([ 1.,  1.,  1.,  1.]),
#  'split5_test_accuracy': array([ 0.72727273,  0.78787879,  0.78787879,  0.78787879]),
#  'split5_test_f1_macro': array([ 0.72727273,  0.78787879,  0.78787879,  0.78787879]),
#  'split5_test_f1_micro': array([ 0.72727273,  0.78787879,  0.78787879,  0.78787879]),
#  'split5_test_precision_macro': array([ 0.73333333,  0.79444444,  0.79444444,  0.79444444]),
#  'split5_test_precision_micro': array([ 0.72727273,  0.78787879,  0.78787879,  0.78787879]),
#  'split5_test_recall_macro': array([ 0.73333333,  0.79444444,  0.79444444,  0.79444444]),
#  'split5_test_recall_micro': array([ 0.72727273,  0.78787879,  0.78787879,  0.78787879]),
#  'split5_test_scores_f_1_0': array([ 0.72727273,  0.78787879,  0.78787879,  0.78787879]),
#  'split5_test_scores_f_1_1': array([ 0.72727273,  0.78787879,  0.78787879,  0.78787879]),
#  'split5_test_scores_p_0': array([ 0.8       ,  0.86666667,  0.86666667,  0.86666667]),
#  'split5_test_scores_p_1': array([ 0.66666667,  0.72222222,  0.72222222,  0.72222222]),
#  'split5_test_scores_r_0': array([ 0.66666667,  0.72222222,  0.72222222,  0.72222222]),
#  'split5_test_scores_r_1': array([ 0.8       ,  0.86666667,  0.86666667,  0.86666667]),
#  'split5_test_tnr': array([ 0.66666667,  0.72222222,  0.72222222,  0.72222222]),
#  'split5_train_accuracy': array([ 1.,  1.,  1.,  1.]),
#  'split5_train_f1_macro': array([ 1.,  1.,  1.,  1.]),
#  'split5_train_f1_micro': array([ 1.,  1.,  1.,  1.]),
#  'split5_train_precision_macro': array([ 1.,  1.,  1.,  1.]),
#  'split5_train_precision_micro': array([ 1.,  1.,  1.,  1.]),
#  'split5_train_recall_macro': array([ 1.,  1.,  1.,  1.]),
#  'split5_train_recall_micro': array([ 1.,  1.,  1.,  1.]),
#  'split5_train_scores_f_1_0': array([ 1.,  1.,  1.,  1.]),
#  'split5_train_scores_f_1_1': array([ 1.,  1.,  1.,  1.]),
#  'split5_train_scores_p_0': array([ 1.,  1.,  1.,  1.]),
#  'split5_train_scores_p_1': array([ 1.,  1.,  1.,  1.]),
#  'split5_train_scores_r_0': array([ 1.,  1.,  1.,  1.]),
#  'split5_train_scores_r_1': array([ 1.,  1.,  1.,  1.]),
#  'split5_train_tnr': array([ 1.,  1.,  1.,  1.]),
#  'split6_test_accuracy': array([ 0.63636364,  0.6969697 ,  0.72727273,  0.66666667]),
#  'split6_test_f1_macro': array([ 0.62781955,  0.68269231,  0.7102439 ,  0.64585366]),
#  'split6_test_f1_micro': array([ 0.63636364,  0.6969697 ,  0.72727273,  0.66666667]),
#  'split6_test_precision_macro': array([ 0.63235294,  0.68045113,  0.70769231,  0.64423077]),
#  'split6_test_precision_micro': array([ 0.63636364,  0.6969697 ,  0.72727273,  0.66666667]),
#  'split6_test_recall_macro': array([ 0.64285714,  0.69047619,  0.71428571,  0.64880952]),
#  'split6_test_recall_micro': array([ 0.63636364,  0.6969697 ,  0.72727273,  0.66666667]),
#  'split6_test_scores_f_1_0': array([ 0.68421053,  0.75      ,  0.7804878 ,  0.73170732]),
#  'split6_test_scores_f_1_1': array([ 0.57142857,  0.61538462,  0.64      ,  0.56      ]),
#  'split6_test_scores_p_0': array([ 0.76470588,  0.78947368,  0.8       ,  0.75      ]),
#  'split6_test_scores_p_1': array([ 0.5       ,  0.57142857,  0.61538462,  0.53846154]),
#  'split6_test_scores_r_0': array([ 0.61904762,  0.71428571,  0.76190476,  0.71428571]),
#  'split6_test_scores_r_1': array([ 0.66666667,  0.66666667,  0.66666667,  0.58333333]),
#  'split6_test_tnr': array([ 0.61904762,  0.71428571,  0.76190476,  0.71428571]),
#  'split6_train_accuracy': array([ 1.,  1.,  1.,  1.]),
#  'split6_train_f1_macro': array([ 1.,  1.,  1.,  1.]),
#  'split6_train_f1_micro': array([ 1.,  1.,  1.,  1.]),
#  'split6_train_precision_macro': array([ 1.,  1.,  1.,  1.]),
#  'split6_train_precision_micro': array([ 1.,  1.,  1.,  1.]),
#  'split6_train_recall_macro': array([ 1.,  1.,  1.,  1.]),
#  'split6_train_recall_micro': array([ 1.,  1.,  1.,  1.]),
#  'split6_train_scores_f_1_0': array([ 1.,  1.,  1.,  1.]),
#  'split6_train_scores_f_1_1': array([ 1.,  1.,  1.,  1.]),
#  'split6_train_scores_p_0': array([ 1.,  1.,  1.,  1.]),
#  'split6_train_scores_p_1': array([ 1.,  1.,  1.,  1.]),
#  'split6_train_scores_r_0': array([ 1.,  1.,  1.,  1.]),
#  'split6_train_scores_r_1': array([ 1.,  1.,  1.,  1.]),
#  'split6_train_tnr': array([ 1.,  1.,  1.,  1.]),
#  'split7_test_accuracy': array([ 0.81818182,  0.72727273,  0.72727273,  0.72727273]),
#  'split7_test_f1_macro': array([ 0.81390977,  0.71794872,  0.71794872,  0.71794872]),
#  'split7_test_f1_micro': array([ 0.81818182,  0.72727273,  0.72727273,  0.72727273]),
#  'split7_test_precision_macro': array([ 0.81433824,  0.71666667,  0.71666667,  0.71666667]),
#  'split7_test_precision_micro': array([ 0.81818182,  0.72727273,  0.72727273,  0.72727273]),
#  'split7_test_recall_macro': array([ 0.83928571,  0.73214286,  0.73214286,  0.73214286]),
#  'split7_test_recall_micro': array([ 0.81818182,  0.72727273,  0.72727273,  0.72727273]),
#  'split7_test_scores_f_1_0': array([ 0.84210526,  0.76923077,  0.76923077,  0.76923077]),
#  'split7_test_scores_f_1_1': array([ 0.78571429,  0.66666667,  0.66666667,  0.66666667]),
#  'split7_test_scores_p_0': array([ 0.94117647,  0.83333333,  0.83333333,  0.83333333]),
#  'split7_test_scores_p_1': array([ 0.6875,  0.6   ,  0.6   ,  0.6   ]),
#  'split7_test_scores_r_0': array([ 0.76190476,  0.71428571,  0.71428571,  0.71428571]),
#  'split7_test_scores_r_1': array([ 0.91666667,  0.75      ,  0.75      ,  0.75      ]),
#  'split7_test_tnr': array([ 0.76190476,  0.71428571,  0.71428571,  0.71428571]),
#  'split7_train_accuracy': array([ 1.,  1.,  1.,  1.]),
#  'split7_train_f1_macro': array([ 1.,  1.,  1.,  1.]),
#  'split7_train_f1_micro': array([ 1.,  1.,  1.,  1.]),
#  'split7_train_precision_macro': array([ 1.,  1.,  1.,  1.]),
#  'split7_train_precision_micro': array([ 1.,  1.,  1.,  1.]),
#  'split7_train_recall_macro': array([ 1.,  1.,  1.,  1.]),
#  'split7_train_recall_micro': array([ 1.,  1.,  1.,  1.]),
#  'split7_train_scores_f_1_0': array([ 1.,  1.,  1.,  1.]),
#  'split7_train_scores_f_1_1': array([ 1.,  1.,  1.,  1.]),
#  'split7_train_scores_p_0': array([ 1.,  1.,  1.,  1.]),
#  'split7_train_scores_p_1': array([ 1.,  1.,  1.,  1.]),
#  'split7_train_scores_r_0': array([ 1.,  1.,  1.,  1.]),
#  'split7_train_scores_r_1': array([ 1.,  1.,  1.,  1.]),
#  'split7_train_tnr': array([ 1.,  1.,  1.,  1.]),
#  'split8_test_accuracy': array([ 0.75757576,  0.75757576,  0.78787879,  0.75757576]),
#  'split8_test_f1_macro': array([ 0.7518797 ,  0.7518797 ,  0.78062678,  0.7518797 ]),
#  'split8_test_f1_micro': array([ 0.75757576,  0.75757576,  0.78787879,  0.75757576]),
#  'split8_test_precision_macro': array([ 0.75      ,  0.75      ,  0.77819549,  0.75      ]),
#  'split8_test_precision_micro': array([ 0.75757576,  0.75757576,  0.78787879,  0.75757576]),
#  'split8_test_recall_macro': array([ 0.75961538,  0.75961538,  0.78461538,  0.75961538]),
#  'split8_test_recall_micro': array([ 0.75757576,  0.75757576,  0.78787879,  0.75757576]),
#  'split8_test_scores_f_1_0': array([ 0.71428571,  0.71428571,  0.74074074,  0.71428571]),
#  'split8_test_scores_f_1_1': array([ 0.78947368,  0.78947368,  0.82051282,  0.78947368]),
#  'split8_test_scores_p_0': array([ 0.66666667,  0.66666667,  0.71428571,  0.66666667]),
#  'split8_test_scores_p_1': array([ 0.83333333,  0.83333333,  0.84210526,  0.83333333]),
#  'split8_test_scores_r_0': array([ 0.76923077,  0.76923077,  0.76923077,  0.76923077]),
#  'split8_test_scores_r_1': array([ 0.75,  0.75,  0.8 ,  0.75]),
#  'split8_test_tnr': array([ 0.76923077,  0.76923077,  0.76923077,  0.76923077]),
#  'split8_train_accuracy': array([ 1.,  1.,  1.,  1.]),
#  'split8_train_f1_macro': array([ 1.,  1.,  1.,  1.]),
#  'split8_train_f1_micro': array([ 1.,  1.,  1.,  1.]),
#  'split8_train_precision_macro': array([ 1.,  1.,  1.,  1.]),
#  'split8_train_precision_micro': array([ 1.,  1.,  1.,  1.]),
#  'split8_train_recall_macro': array([ 1.,  1.,  1.,  1.]),
#  'split8_train_recall_micro': array([ 1.,  1.,  1.,  1.]),
#  'split8_train_scores_f_1_0': array([ 1.,  1.,  1.,  1.]),
#  'split8_train_scores_f_1_1': array([ 1.,  1.,  1.,  1.]),
#  'split8_train_scores_p_0': array([ 1.,  1.,  1.,  1.]),
#  'split8_train_scores_p_1': array([ 1.,  1.,  1.,  1.]),
#  'split8_train_scores_r_0': array([ 1.,  1.,  1.,  1.]),
#  'split8_train_scores_r_1': array([ 1.,  1.,  1.,  1.]),
#  'split8_train_tnr': array([ 1.,  1.,  1.,  1.]),
#  'split9_test_accuracy': array([ 0.72727273,  0.6969697 ,  0.72727273,  0.72727273]),
#  'split9_test_f1_macro': array([ 0.72626728,  0.69444444,  0.72626728,  0.72626728]),
#  'split9_test_f1_micro': array([ 0.72727273,  0.6969697 ,  0.72727273,  0.72727273]),
#  'split9_test_precision_macro': array([ 0.79545455,  0.7826087 ,  0.79545455,  0.79545455]),
#  'split9_test_precision_micro': array([ 0.72727273,  0.6969697 ,  0.72727273,  0.72727273]),
#  'split9_test_recall_macro': array([ 0.775,  0.75 ,  0.775,  0.775]),
#  'split9_test_recall_micro': array([ 0.72727273,  0.6969697 ,  0.72727273,  0.72727273]),
#  'split9_test_scores_f_1_0': array([ 0.74285714,  0.72222222,  0.74285714,  0.74285714]),
#  'split9_test_scores_f_1_1': array([ 0.70967742,  0.66666667,  0.70967742,  0.70967742]),
#  'split9_test_scores_p_0': array([ 0.59090909,  0.56521739,  0.59090909,  0.59090909]),
#  'split9_test_scores_p_1': array([ 1.,  1.,  1.,  1.]),
#  'split9_test_scores_r_0': array([ 1.,  1.,  1.,  1.]),
#  'split9_test_scores_r_1': array([ 0.55,  0.5 ,  0.55,  0.55]),
#  'split9_test_tnr': array([ 1.,  1.,  1.,  1.]),
#  'split9_train_accuracy': array([ 1.,  1.,  1.,  1.]),
#  'split9_train_f1_macro': array([ 1.,  1.,  1.,  1.]),
#  'split9_train_f1_micro': array([ 1.,  1.,  1.,  1.]),
#  'split9_train_precision_macro': array([ 1.,  1.,  1.,  1.]),
#  'split9_train_precision_micro': array([ 1.,  1.,  1.,  1.]),
#  'split9_train_recall_macro': array([ 1.,  1.,  1.,  1.]),
#  'split9_train_recall_micro': array([ 1.,  1.,  1.,  1.]),
#  'split9_train_scores_f_1_0': array([ 1.,  1.,  1.,  1.]),
#  'split9_train_scores_f_1_1': array([ 1.,  1.,  1.,  1.]),
#  'split9_train_scores_p_0': array([ 1.,  1.,  1.,  1.]),
#  'split9_train_scores_p_1': array([ 1.,  1.,  1.,  1.]),
#  'split9_train_scores_r_0': array([ 1.,  1.,  1.,  1.]),
#  'split9_train_scores_r_1': array([ 1.,  1.,  1.,  1.]),
#  'split9_train_tnr': array([ 1.,  1.,  1.,  1.]),
#  'std_fit_time': array([ 0.26329357,  0.44027098,  1.66726403,  4.92856247]),
#  'std_score_time': array([ 0.47741716,  2.38538217,  2.41770743,  3.66761822]),
#  'std_test_accuracy': array([ 0.04858449,  0.031818  ,  0.03720822,  0.03982833]),
#  'std_test_f1_macro': array([ 0.0489584 ,  0.03235351,  0.03681551,  0.04177999]),
#  'std_test_f1_micro': array([ 0.04858449,  0.031818  ,  0.03720822,  0.03982833]),
#  'std_test_precision_macro': array([ 0.05289174,  0.03889868,  0.04076644,  0.04995263]),
#  'std_test_precision_micro': array([ 0.04858449,  0.031818  ,  0.03720822,  0.03982833]),
#  'std_test_recall_macro': array([ 0.0534088 ,  0.03352605,  0.03902024,  0.04742415]),
#  'std_test_recall_micro': array([ 0.04858449,  0.031818  ,  0.03720822,  0.03982833]),
#  'std_test_scores_f_1_0': array([ 0.04790415,  0.03700033,  0.03858661,  0.03978293]),
#  'std_test_scores_f_1_1': array([ 0.06549728,  0.05257635,  0.05966852,  0.06537613]),
#  'std_test_scores_p_0': array([ 0.09923036,  0.0937773 ,  0.09036078,  0.09122264]),
#  'std_test_scores_p_1': array([ 0.1278405 ,  0.12220158,  0.10762909,  0.12573068]),
#  'std_test_scores_r_0': array([ 0.10380022,  0.09503995,  0.07964848,  0.08959821]),
#  'std_test_scores_r_1': array([ 0.10937084,  0.09749004,  0.09819573,  0.09520498]),
#  'std_test_tnr': array([ 0.10380022,  0.09503995,  0.07964848,  0.08959821]),
#  'std_train_accuracy': array([ 0.,  0.,  0.,  0.]),
#  'std_train_f1_macro': array([ 0.,  0.,  0.,  0.]),
#  'std_train_f1_micro': array([ 0.,  0.,  0.,  0.]),
#  'std_train_precision_macro': array([ 0.,  0.,  0.,  0.]),
#  'std_train_precision_micro': array([ 0.,  0.,  0.,  0.]),
#  'std_train_recall_macro': array([ 0.,  0.,  0.,  0.]),
#  'std_train_recall_micro': array([ 0.,  0.,  0.,  0.]),
#  'std_train_scores_f_1_0': array([ 0.,  0.,  0.,  0.]),
#  'std_train_scores_f_1_1': array([ 0.,  0.,  0.,  0.]),
#  'std_train_scores_p_0': array([ 0.,  0.,  0.,  0.]),
#  'std_train_scores_p_1': array([ 0.,  0.,  0.,  0.]),
#  'std_train_scores_r_0': array([ 0.,  0.,  0.,  0.]),
#  'std_train_scores_r_1': array([ 0.,  0.,  0.,  0.]),
#  'std_train_tnr': array([ 0.,  0.,  0.,  0.])}

# %%
def get_table_from_files(files):
    table = {'classifier': [], 'drug': [], 'feature':[],'f1_macro':[],'precision_micro':[],'precision_macro':[],'recall_micro':[],'recall_macro':[],'accuracy':[],'tnr':[],'scores_p_0':[],'scores_r_0':[],'scores_f_1_0':[],'scores_p_1':[],'scores_r_1':[],'scores_f_1_1':[]}
    drugs=['Ceftazidim','Tobramycin','Meropenem','Colistin','Ciprofloxacin']
    for file in files:        
        drug_feature_classifier=file.split('/')[-1].replace('.pickle','').split('_')
        for drug in drugs:
            if drug in drug_feature_classifier[0]:
                drug_feature_classifier.insert(0,drug)
                drug_feature_classifier[1]=drug_feature_classifier[1].replace(drug,'')
                drug_feature_classifier=[drug_feature_classifier[0],'_'.join(drug_feature_classifier[1:-1]),drug_feature_classifier[-1]]
                res=get_cv_res(file)
                for key in table:
                    if key=='classifier':
                        if not drug_feature_classifier[-1]=='SVM':
                            table['classifier'].append(drug_feature_classifier[-1])
                    elif key=='drug':
                        if not drug_feature_classifier[-1]=='SVM':
                            table['drug'].append(drug_feature_classifier[0])
                    elif key=='feature':
                        if not drug_feature_classifier[-1]=='SVM':
                            table['feature'].append(drug_feature_classifier[1])
                    else:
                        if not drug_feature_classifier[-1]=='SVM':
                            table[key].append(res[key])
    return pd.DataFrame(data=table,columns=['drug', 'feature','classifier','f1_macro','scores_r_0','accuracy','tnr','precision_micro','precision_macro','recall_micro','recall_macro','scores_p_0','scores_r_0','scores_f_1_0','scores_p_1','scores_r_1','scores_f_1_1'])

# %%
path2res='/mounts/data/proj/asgari/dissertation/git_repos/amr_results/results/classifications_standard/'
files_block=FileUtility.recursive_glob(path2res,'*.pickle')
path2res='/mounts/data/proj/asgari/dissertation/git_repos/amr_results/results/classifications_block/'
files_std=FileUtility.recursive_glob(path2res,'*.pickle')

# %%
writer = pd.ExcelWriter('output.xlsx')
get_table_from_files(files_block).to_excel(writer,'block')
get_table_from_files(files_std).to_excel(writer,'standard')
writer.save()
# Out:
# /mounts/Users/student/asgari/.local/lib/python3.4/site-packages/sklearn/base.py:311: UserWarning: Trying to unpickle estimator LinearSVC from version 0.19.0 when using version 0.19.1. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# /mounts/Users/student/asgari/.local/lib/python3.4/site-packages/sklearn/base.py:311: UserWarning: Trying to unpickle estimator DecisionTreeClassifier from version 0.19.0 when using version 0.19.1. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# /mounts/Users/student/asgari/.local/lib/python3.4/site-packages/sklearn/base.py:311: UserWarning: Trying to unpickle estimator RandomForestClassifier from version 0.19.0 when using version 0.19.1. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# /mounts/Users/student/asgari/.local/lib/python3.4/site-packages/sklearn/base.py:311: UserWarning: Trying to unpickle estimator KNeighborsClassifier from version 0.19.0 when using version 0.19.1. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
