# %%
import sys
sys.path.append('../')

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import manifold
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from utility.visualization_utility import plot_scatter
# %pylab inline
# %matplotlib inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Phylogenetic projection to 100d

# %%
isolates = [l.split()[0] for l in open("../data_config/distance.txt", "r").readlines()]
adist = np.array([[float(x) for x in l.split()[1::]] for l in open("../data_config/distance.txt", "r").readlines()])


amax = np.amax(adist)
adist /= amax
mds = manifold.MDS(n_components=100, dissimilarity="precomputed", random_state=6)
results = mds.fit(adist)
embeddings = results.embedding_

# %%
from drug_analysis.drug_relation_analysis import DrugRelation

DR = DrugRelation()
DR.make_drug_vector()

# %%
labeled_and_tree_ed_isolates=list(set(isolates).intersection(DR.BasicDataObj.labeled_isolates))
labeled_and_tree_ed_isolates.sort()

# %%
index_on_phentype_vector=[DR.BasicDataObj.labeled_isolates.index(x) for x in labeled_and_tree_ed_isolates]
index_on_phylogenetic_embedding=[isolates.index(x) for x in labeled_and_tree_ed_isolates]

# %% [markdown]
# ## Visualization

# %%
def get_pca_tsne(X):    
    X_pca = PCA(n_components=50).fit_transform(X)
    X_tsne = TSNE(n_components=2, perplexity=40, verbose=2, learning_rate=10).fit_transform(X)
    return X_pca, X_tsne

# %%
X_pca, X_tsne=get_pca_tsne(embeddings)
# Out:
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 508 samples in 0.002s...
# [t-SNE] Computed neighbors for 508 samples in 0.079s...
# [t-SNE] Computed conditional probabilities for sample 508 / 508
# [t-SNE] Mean sigma: 0.009557
# [t-SNE] Computed conditional probabilities in 0.036s
# [t-SNE] Iteration 50: error = 53.9686470, gradient norm = 0.0782832 (50 iterations in 0.372s)
# [t-SNE] Iteration 100: error = 49.8247948, gradient norm = 0.0063997 (50 iterations in 0.341s)
# [t-SNE] Iteration 150: error = 49.3743210, gradient norm = 0.0033013 (50 iterations in 0.326s)
# [t-SNE] Iteration 200: error = 49.1928711, gradient norm = 0.0023918 (50 iterations in 0.322s)
# [t-SNE] Iteration 250: error = 49.0926514, gradient norm = 0.0018212 (50 iterations in 0.351s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 49.092651
# [t-SNE] Iteration 300: error = 0.5643814, gradient norm = 0.0057751 (50 iterations in 0.329s)
# [t-SNE] Iteration 350: error = 0.3573641, gradient norm = 0.0015519 (50 iterations in 0.349s)
# [t-SNE] Iteration 400: error = 0.2986008, gradient norm = 0.0008161 (50 iterations in 0.347s)
# [t-SNE] Iteration 450: error = 0.2695271, gradient norm = 0.0006135 (50 iterations in 0.346s)
# [t-SNE] Iteration 500: error = 0.2547760, gradient norm = 0.0003420 (50 iterations in 0.347s)
# [t-SNE] Iteration 550: error = 0.2474528, gradient norm = 0.0002442 (50 iterations in 0.348s)
# [t-SNE] Iteration 600: error = 0.2426367, gradient norm = 0.0001830 (50 iterations in 0.349s)
# [t-SNE] Iteration 650: error = 0.2400565, gradient norm = 0.0001515 (50 iterations in 0.348s)
# [t-SNE] Iteration 700: error = 0.2381971, gradient norm = 0.0001393 (50 iterations in 0.348s)
# [t-SNE] Iteration 750: error = 0.2371041, gradient norm = 0.0001144 (50 iterations in 0.351s)
# [t-SNE] Iteration 800: error = 0.2361376, gradient norm = 0.0001090 (50 iterations in 0.344s)
# [t-SNE] Iteration 850: error = 0.2353217, gradient norm = 0.0001205 (50 iterations in 0.359s)
# [t-SNE] Iteration 900: error = 0.2346343, gradient norm = 0.0000994 (50 iterations in 0.350s)
# [t-SNE] Iteration 950: error = 0.2341735, gradient norm = 0.0000867 (50 iterations in 0.350s)
# [t-SNE] Iteration 1000: error = 0.2338326, gradient norm = 0.0000933 (50 iterations in 0.355s)
# [t-SNE] Error after 1000 iterations: 0.233833

# %%
phenotype_dict={1:'Resistance',0.5:'Intermediate Resitance',0:'Susceptive'}
myplot=figure(figsize=(16,24))
for idx,drug in enumerate(DR.drugs):
    embedding=X_tsne[index_on_phylogenetic_embedding,:]
    Y=[phenotype_dict[x] for x in DR.drug_vectors[idx,index_on_phentype_vector]]
    ax=subplot(3,2,(idx+1))
    if idx==3:
        plot_scatter(ax, embedding, Y, 't-SNE_1', 't-SNE_0', 'Resistance to '+drug, legend_hide=False,  legend_loc=9, legend_col=1,  legend_size=20, font_s=40,label_dict=None, color_schemes_idx=0)
    else:
        plot_scatter(ax, embedding, Y, 't-SNE_1', 't-SNE_0', 'Resistance to '+drug, legend_hide=True, font_s=40,label_dict=None, color_schemes_idx=0)
    plt.title('Resistance to '+drug, fontsize=20)

# %%
myplot.savefig('../results/figures/phylogenetic_phenotype.pdf')

# %% [markdown]
# ## Classification

# %%
from classifier.classical_classifiers import SVM, RFClassifier, KNN

phenotype_dict={1:'Resistance', 0.5:'Intermediate/Susceptive', 0:'Intermediate/Susceptive'}
myplot=figure(figsize=(16,24))
for idx,drug in enumerate(DR.drugs):
    X_rep=embeddings[index_on_phylogenetic_embedding,:]
    Y=[phenotype_dict[x] for x in DR.drug_vectors[idx,index_on_phentype_vector]]
    MRF = RFClassifier(X, Y)
    MRF.tune_and_eval('../results/classification/phylogenetic_based/phylogenetic_10xfold_')
    MSVM = SVM(X, Y)
    MSVM.tune_and_eval('../results/classification/phylogenetic_based/phylogenetic_10xfold_')
    MKNN = KNN(X, Y)
    MKNN.tune_and_eval('../results/classification/phylogenetic_based/phylogenetic_10xfold_')
