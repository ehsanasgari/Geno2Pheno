# %%
import sys
sys.path.append('../')
from utility.file_utility import FileUtility
import pandas as pd
from pandas import Series
import numpy as np
import pandas as pd
from scipy import stats, integrate
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib
from sklearn.metrics import f1_score

# %%
def warn(*args, **kwargs):
    pass
import warnings
warnings.warn = warn

# %%
phenotypes_best_features={'Tobramycin_S-vs-R':'genexp##gpa##roary', 'Ceftazidim_S-vs-R':'genexp##snps##gpa##roary', 'Ciprofloxacin_S-vs-R':'snps##gpa##roary', 'Meropenem_S-vs-R':'genexp##gpa##roary'}

# %%
table={'Cross-validation':[],'Validation set':[],'Drug':[],'Classifier':[],'Cross-validation-type':[]}

for drug, feature in phenotypes_best_features.items():
    
    result_files=FileUtility.recursive_glob('/mounts/data/proj/asgari/Pseudogenomics/classifications/S_vs_R_tree_cv/'+drug,feature+'_*.pickle')
    result_files+=FileUtility.recursive_glob('/mounts/data/proj/asgari/Pseudogenomics/classifications/S_vs_R_std_cv/'+drug,feature+'_*.pickle')
    
    for file in result_files:
        classifier=file.split('_')[-1].replace('.pickle','')
        cv=file.split('_CV_')[-1].split('_')[0]
        feature=file.split('/')[-1].split('_')[0]
        phenotype=file.split('/')[0:-1][-1]
        fold_files=FileUtility.recursive_glob('/'.join(file.split('/')[0:-1])+'/cv/','*.txt')
        fold_files.sort()
        [label_set, conf, label_set, best_score_, best_estimator_,
                                  cv_results_, best_params_,  (cv_predictions_pred,cv_predictions_trues,isolates), (Y_test_pred, Y_test) ]=FileUtility.load_obj(file)

        macro_f1_mean=cv_results_['mean_test_f1_macro'][np.argmax(cv_results_['mean_test_f1_macro'])]
        macro_f1_std=cv_results_['std_test_f1_macro'][np.argmax(cv_results_['mean_test_f1_macro'])]
        test_macro_f1=f1_score(Y_test_pred, Y_test,average='macro')
        samples = np.random.normal(macro_f1_mean, macro_f1_std, 100).tolist()
        for v in samples:
            table['Cross-validation'].append(v)
            table['Validation set'].append(test_macro_f1)
            table['Classifier'].append(classifier)
            table['Drug'].append(phenotype)
            table['Cross-validation-type'].append(cv)
df=pd.DataFrame(table)

# %%
df['Cross-validation-type']=['block' if x=='tree' else 'std' for x in df['Cross-validation-type'].tolist()]
df['Classifier / cv scheme']=df['Classifier'] +' / '+ df['Cross-validation-type']
df['Drug']=[x.replace('_S-vs-R','') for x in df['Drug'].tolist()]

# %%
pal=sns.color_palette('bright')

# %%
import seaborn as sns 
# Grouped boxplot
f, ax = plt.subplots(figsize=(40, 20))

font_s=15
params = {
    'legend.fontsize': 30,
    'xtick.labelsize': 40,
    'ytick.labelsize': 40,
    'text.usetex': True,
}
matplotlib.rcParams['mathtext.fontset'] = 'stix'
matplotlib.rcParams['font.family'] = 'STIXGeneral'
matplotlib.rcParams['mathtext.fontset'] = 'custom'
matplotlib.rcParams['mathtext.rm'] = 'Bitstream Vera Sans'
matplotlib.rcParams['mathtext.it'] = 'Bitstream Vera Sans:italic'
matplotlib.rcParams['mathtext.bf'] = 'Bitstream Vera Sans:bold'
plt.rc('text', usetex=True)
plt.rcParams.update(params)

#df1=df[df['Cross-validation-type']=='tree']
sns.barplot(x="Drug", y="Cross-validation", hue="Classifier / cv scheme",data=df, palette = [pal[0],pal[1],pal[3],'#7e70ff','#ffc497','#ff8d9e'])

plt.xlabel('Antibacterial agents',fontsize= 50)
plt.ylabel('Macro-F1 in cross-validation',fontsize= 50)
plt.title('Comparison of different machine learning classifiers for antibacterial resisatnce prediction',fontsize= 50)

#sns.pointplot(x="Drug", y="Validation set", hue="Classifier", data=df1, palette="Set2")
#df2=df[df['Cross-validation-type']=='rand']
#sns.barplot(x="Drug", y="Cross-validation", hue="Classifier", data=df2, palette="Set2")
#sns.plt.show()
plt.savefig('classifier_cv.pdf')

# %%
import seaborn as sns 
# Grouped boxplot
f, ax = plt.subplots(figsize=(40, 20))

font_s=15
params = {
    'legend.fontsize': 30,
    'xtick.labelsize': 40,
    'ytick.labelsize': 40,
    'text.usetex': True,
}
matplotlib.rcParams['mathtext.fontset'] = 'stix'
matplotlib.rcParams['font.family'] = 'STIXGeneral'
matplotlib.rcParams['mathtext.fontset'] = 'custom'
matplotlib.rcParams['mathtext.rm'] = 'Bitstream Vera Sans'
matplotlib.rcParams['mathtext.it'] = 'Bitstream Vera Sans:italic'
matplotlib.rcParams['mathtext.bf'] = 'Bitstream Vera Sans:bold'
plt.rc('text', usetex=True)
plt.rcParams.update(params)

#df1=df[df['Cross-validation-type']=='tree']
sns.barplot(x="Drug", y="Validation set", hue="Classifier / cv scheme",data=df, palette =  [pal[0],pal[1],pal[3],'#7e70ff','#ffc497','#ff8d9e'])
plt.xlabel('Antibacterial agents',fontsize= 50)
plt.ylabel('Macro-F1 over the held-out set',fontsize= 50)
plt.title('Comparison of different machine learning classifiers for antibacterial resisatnce prediction',fontsize= 50)

#sns.pointplot(x="Drug", y="Validation set", hue="Classifier", data=df1, palette="Set2")
#df2=df[df['Cross-validation-type']=='rand']
#sns.barplot(x="Drug", y="Cross-validation", hue="Classifier", data=df2, palette="Set2")
#sns.plt.show()
plt.savefig('classifier_test.pdf')

# %%
df2=df[df['Cross-validation-type']=='rand']
# Grouped boxplot
f, ax = plt.subplots(figsize=(11, 9))
sns.barplot(x="Drug", y="Cross-validation", hue="Classifier", data=df2, palette="Set1")

# %%
cv_results_['mean_test_f1_macro'][np.argmax(cv_results_['mean_test_f1_macro'])]
# Out:
# 0.7851830036814846

# %%
cv_results_['std_test_f1_macro'][np.argmax(cv_results_['mean_test_f1_macro'])]
# Out:
# 0.10501179459931614

# %%
sheets={'CV std Test':'valiation std cv','CV std Cross-val':'cross-val std cv','CV tree Test':'valiation block cv','CV tree Cross-val':'cross-val block cv'}
features=['snps','snps##gpa##roary','genexp##snps##gpa##roary','genexp##gpa##roary','gpa##roary','genexp##snps','genexp']

feature_map={'snps##gpa##roary':'snps-gpa','genexp##snps##gpa##roary':'snps-gpa-genexp','genexp##gpa##roary':'gpa-genexp','gpa##roary':'gpa','genexp##snps':'genexp-snps'}
cls='RF'
phenotypes=['Tobramycin_S-vs-R', 'Ceftazidim_S-vs-R', 'Ciprofloxacin_S-vs-R', 'Meropenem_S-vs-R']
phenotypes.sort()

# %%
result_files
# Out:
# ['/mounts/data/proj/asgari/Pseudogenomics/classifications/S_vs_R_tree_cv/Ciprofloxacin_S-vs-R/genexp##gpa##roary_CV_tree_SVM.pickle',
#  '/mounts/data/proj/asgari/Pseudogenomics/classifications/S_vs_R_tree_cv/Ciprofloxacin_S-vs-R/genexp##gpa##roary_CV_tree_RF.pickle',
#  '/mounts/data/proj/asgari/Pseudogenomics/classifications/S_vs_R_tree_cv/Ciprofloxacin_S-vs-R/genexp##gpa##roary_CV_tree_LR.pickle',
#  '/mounts/data/proj/asgari/Pseudogenomics/classifications/S_vs_R_tree_cv/Meropenem_S-vs-R/genexp##gpa##roary_CV_tree_SVM.pickle',
#  '/mounts/data/proj/asgari/Pseudogenomics/classifications/S_vs_R_tree_cv/Meropenem_S-vs-R/genexp##gpa##roary_CV_tree_RF.pickle',
#  '/mounts/data/proj/asgari/Pseudogenomics/classifications/S_vs_R_tree_cv/Meropenem_S-vs-R/genexp##gpa##roary_CV_tree_LR.pickle',
#  '/mounts/data/proj/asgari/Pseudogenomics/classifications/S_vs_R_tree_cv/Tobramycin_S-vs-R/genexp##gpa##roary_CV_tree_SVM.pickle',
# ...

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x="State", y="Rates.Property.All",
              data=state_crime_four_states, 
              hue='old_new', dodge=True);

# %%
import seaborn as sns
df = sns.load_dataset('tips')
 
# Grouped boxplot
sns.boxplot(x="day", y="total_bill", hue="smoker", data=df, palette="Set1")
#sns.plt.show()

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 12        15.42  1.57    Male     No   Sun  Dinner     2
# 13        18.43  3.00    Male     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# ...
