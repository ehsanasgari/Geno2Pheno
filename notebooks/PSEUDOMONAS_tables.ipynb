# %%
import sys
sys.path.append('../')
from utility.file_utility import FileUtility
import pandas as pd
from pandas import Series

# %%
df=pd.read_table('/mounts/data/proj/asgari/final_proj/Geno2Pheno/data_config/pheno_table_CLSI_S-vs-R.txt')

# %%
df['sum']=df[['Tobramycin_S-vs-R','Ceftazidim_S-vs-R','Ciprofloxacin_S-vs-R','Meropenem_S-vs-R']].max(axis=1)

# %%
df[df['sum']==0]
# Out:
#     final_all  Tobramycin_S-vs-R  Ceftazidim_S-vs-R  Ciprofloxacin_S-vs-R  \
# 5      CH2527                0.0                0.0                   0.0
# 10     CH2597                0.0                NaN                   NaN
# 24     CH2680                0.0                NaN                   0.0
# 28     CH2690                0.0                0.0                   0.0
# 35     CH2718                0.0                0.0                   0.0
# 37     CH2730                0.0                0.0                   0.0
# 42     CH2756                0.0                0.0                   0.0
# 45     CH2829                0.0                0.0                   0.0
# 46     CH2848                0.0                NaN                   0.0
# 49     CH2922                0.0                0.0                   0.0
# 50     CH2939                0.0                0.0                   0.0
# 58     CH3549                0.0                0.0                   0.0
# 64     CH3906                0.0                0.0                   0.0
# 68     CH4418                0.0                NaN                   0.0
# 72     CH4446                0.0                0.0                   NaN
# 74     CH4509                0.0                0.0                   0.0
# 75     CH4520                0.0                NaN                   0.0
# 78     CH4549                0.0                0.0                   0.0
# 81     CH4591                0.0                0.0                   NaN
# 82     CH4602                0.0                0.0                   0.0
# 85     CH4684                0.0                NaN                   0.0
# 88     CH4733                0.0                0.0                   0.0
# 100    CH4891                0.0                0.0                   0.0
# 101    CH4914                0.0                0.0                   0.0
# 113    CH5262                0.0                0.0                   0.0
# 119    CH5362                0.0                0.0                   NaN
# 140    ESP003                0.0                0.0                   0.0
# 143    ESP009                0.0                0.0                   NaN
# 144    ESP011                0.0                0.0                   0.0
# 147    ESP015                0.0                0.0                   0.0
# ..        ...                ...                ...                   ...
# 350  PSAE1401                0.0                0.0                   0.0
# 353  PSAE1630                0.0                0.0                   NaN
# 354  PSAE1635                0.0                0.0                   NaN
# 356  PSAE1642                0.0                0.0                   0.0
# 358  PSAE1647                0.0                0.0                   NaN
# 359  PSAE1649                0.0                0.0                   0.0
# 360  PSAE1651                0.0                0.0                   NaN
# 361  PSAE1654                0.0                0.0                   NaN
# 362  PSAE1656                0.0                0.0                   0.0
# 365  PSAE1837                0.0                0.0                   0.0
# 370  PSAE1970                0.0                0.0                   NaN
# 372  PSAE1984                0.0                0.0                   0.0
# 383  ZG205565                0.0                0.0                   NaN
# 384  ZG205694                0.0                0.0                   0.0
# 385  ZG205710                0.0                0.0                   NaN
# 388  ZG302359                0.0                0.0                   0.0
# 389  ZG302367                0.0                0.0                   0.0
# 390  ZG302368                0.0                0.0                   0.0
# 392  ZG302383                0.0                0.0                   0.0
# 393  ZG302431                0.0                0.0                   0.0
# 394  ZG302432                0.0                0.0                   0.0
# 395  ZG302442                0.0                0.0                   0.0
# 396  ZG302451                0.0                0.0                   0.0
# 397  ZG314696                0.0                0.0                   0.0
# 398  ZG314738                0.0                0.0                   0.0
# 399  ZG314777                0.0                0.0                   0.0
# 400  ZG316694                0.0                0.0                   0.0
# 401  ZG316704                0.0                0.0                   0.0
# 402  ZG316716                0.0                0.0                   0.0
# 403  ZG316722                0.0                0.0                   0.0
#
#      Meropenem_S-vs-R  Colistin_S-vs-R  sum
# 5                 0.0                0  0.0
# 10                0.0                0  0.0
# 24                0.0                0  0.0
# 28                0.0                0  0.0
# 35                NaN                1  0.0
# 37                NaN                0  0.0
# 42                0.0                1  0.0
# 45                0.0                0  0.0
# 46                0.0                0  0.0
# 49                0.0                0  0.0
# 50                0.0                0  0.0
# 58                NaN                0  0.0
# 64                0.0                0  0.0
# 68                0.0                0  0.0
# 72                NaN                0  0.0
# 74                0.0                1  0.0
# 75                0.0                1  0.0
# 78                NaN                0  0.0
# 81                NaN                0  0.0
# 82                0.0                0  0.0
# 85                0.0                0  0.0
# 88                0.0                0  0.0
# 100               0.0                0  0.0
# 101               0.0                1  0.0
# 113               0.0                0  0.0
# 119               NaN                0  0.0
# 140               0.0                0  0.0
# 143               0.0                0  0.0
# 144               0.0                0  0.0
# 147               0.0                0  0.0
# ..                ...              ...  ...
# 350               NaN                1  0.0
# 353               NaN                0  0.0
# 354               NaN                0  0.0
# 356               0.0                0  0.0
# 358               NaN                0  0.0
# 359               0.0                0  0.0
# 360               NaN                0  0.0
# 361               NaN                0  0.0
# 362               0.0                0  0.0
# 365               0.0                0  0.0
# 370               NaN                0  0.0
# 372               NaN                1  0.0
# 383               0.0                0  0.0
# 384               0.0                0  0.0
# 385               0.0                0  0.0
# 388               0.0                0  0.0
# 389               0.0                1  0.0
# 390               0.0                0  0.0
# 392               0.0                0  0.0
# 393               0.0                1  0.0
# 394               0.0                0  0.0
# 395               0.0                0  0.0
# 396               0.0                0  0.0
# 397               0.0                0  0.0
# 398               0.0                0  0.0
# 399               NaN                0  0.0
# 400               0.0                0  0.0
# 401               0.0                0  0.0
# 402               0.0                0  0.0
# 403               0.0                0  0.0
#
# [99 rows x 7 columns]

# %%
settings=['Tobramycin_S-vs-R','Ceftazidim_S-vs-R','Ciprofloxacin_S-vs-R','Meropenem_S-vs-R']

# %%
for setting in settings:
    df_temp=df[df[setting]>=0][['final all',setting]]
    dict_of_val=Series(df_temp[setting].values,index=df_temp['final all']).to_dict() 
    lines=['\t'.join([x,str(int(y))]) for x,y in dict_of_val.items()]
    FileUtility.save_list('/mounts/data/proj/asgari/final_proj/Geno2Pheno/data_config/pseudogenomics/'+setting+'.txt',lines)

# %%
# Out:
# ['CF592_Iso2\t0',
#  'CH2500\t0',
#  'CH2502\t0',
#  'CH2522\t0',
#  'CH2527\t0',
#  'CH2543\t1',
#  'CH2560\t1',
#  'CH2582\t0',
#  'CH2591\t1',
#  'CH2597\t0',
#  'CH2598\t0',
#  'CH2608\t1',
#  'CH2623\t1',
#  'CH2639\t1',
#  'CH2657\t1',
#  'CH2658\t0',
#  'CH2660\t0',
#  'CH2665\t1',
#  'CH2672\t0',
#  'CH2674\t1',
#  'CH2675\t1',
#  'CH2677\t0',
#  'CH2678\t0',
#  'CH2680\t0',
#  'CH2682\t0',
#  'CH2685\t0',
#  'CH2687\t0',
#  'CH2690\t0',
#  'CH2698\t1',
#  'CH2699\t1',
#  'CH2705\t1',
#  'CH2706\t1',
#  'CH2707\t1',
#  'CH2713\t0',
#  'CH2718\t0',
#  'CH2724\t0',
#  'CH2730\t0',
#  'CH2734\t0',
#  'CH2735\t0',
#  'CH2747\t0',
#  'CH2748\t1',
#  'CH2756\t0',
#  'CH2764\t0',
#  'CH2824\t0',
#  'CH2829\t0',
#  'CH2848\t0',
#  'CH2860\t0',
#  'CH2875\t1',
#  'CH2922\t0',
#  'CH2939\t0',
#  'CH3173\t1',
#  'CH3177\t0',
#  'CH3290\t1',
#  'CH3325\t0',
#  'CH3462\t0',
#  'CH3466\t0',
#  'CH3484\t0',
#  'CH3549\t0',
#  'CH3570\t1',
#  'CH3613\t1',
#  'CH3648\t1',
#  'CH3797\t0',
#  'CH3882\t0',
#  'CH3906\t0',
#  'CH4035\t1',
#  'CH4083\t0',
#  'CH4411\t1',
#  'CH4418\t0',
#  'CH4433\t1',
#  'CH4438\t0',
#  'CH4443\t1',
#  'CH4446\t0',
#  'CH4489\t0',
#  'CH4509\t0',
#  'CH4520\t0',
#  'CH4528\t0',
#  'CH4548\t1',
#  'CH4549\t0',
#  'CH4560\t1',
#  'CH4591\t0',
#  'CH4602\t0',
#  'CH4634\t0',
#  'CH4681\t0',
#  'CH4684\t0',
#  'CH4703\t0',
#  'CH4704\t0',
#  'CH4733\t0',
#  'CH4745\t1',
#  'CH4755\t0',
#  'CH4757\t0',
#  'CH4766\t0',
#  'CH4780\t0',
#  'CH4785\t0',
#  'CH4840\t0',
#  'CH4860\t0',
#  'CH4862\t1',
#  'CH4877\t1',
#  'CH4878\t0',
#  'CH4891\t0',
#  'CH4914\t0',
#  'CH4916\t0',
#  'CH4990\t0',
#  'CH4992\t0',
#  'CH5022\t1',
#  'CH5052\t1',
#  'CH5066\t0',
#  'CH5159\t1',
#  'CH5174\t1',
#  'CH5182\t0',
#  'CH5193\t1',
#  'CH5206\t0',
#  'CH5262\t0',
#  'CH5267\t0',
#  'CH5291\t0',
#  'CH5334\t0',
#  'CH5353\t0',
#  'CH5356\t1',
#  'CH5362\t0',
#  'CH5363\t0',
#  'CH5387\t0',
#  'CH5462\t0',
#  'CH5464\t1',
#  'CH5478\t0',
#  'CH5528\t0',
#  'CH5531\t0',
#  'CH5548\t0',
#  'CH5550\t0',
#  'CH5551\t1',
#  'CH5591\t1',
#  'CH5596\t0',
#  'CH5597\t0',
#  'CH5621\t0',
#  'CH5638\t0',
#  'CH5666\t1',
#  'CH5688\t1',
#  'CH5695\t1',
#  'ESP002\t0',
#  'ESP003\t0',
#  'ESP004\t1',
#  'ESP006\t1',
#  'ESP009\t0',
#  'ESP011\t0',
#  'ESP012\t1',
#  'ESP013\t1',
#  'ESP015\t0',
#  'ESP020\t0',
#  'ESP021\t0',
#  'ESP022\t0',
#  'ESP023\t0',
#  'ESP024\t0',
#  'ESP025\t1',
#  'ESP027\t0',
#  'ESP028\t0',
#  'ESP029\t0',
#  'ESP031\t0',
#  'ESP032\t0',
#  'ESP033\t0',
#  'ESP034\t0',
#  'ESP035\t0',
#  'ESP036\t0',
#  'ESP037\t0',
#  'ESP038\t0',
#  'ESP039\t0',
#  'ESP043\t1',
#  'ESP044\t0',
#  'ESP046\t0',
#  'ESP047\t1',
#  'ESP050\t0',
#  'ESP053\t1',
#  'ESP055\t0',
#  'ESP057\t0',
#  'ESP058\t0',
#  'ESP059\t0',
#  'ESP060\t1',
#  'ESP061\t1',
#  'ESP063\t1',
#  'ESP064\t1',
#  'ESP066\t0',
#  'ESP067\t0',
#  'ESP068\t1',
#  'ESP069\t1',
#  'ESP070\t0',
#  'ESP072\t0',
#  'ESP073\t0',
#  'ESP074\t1',
#  'ESP075\t0',
#  'ESP076\t0',
#  'ESP077\t1',
#  'ESP078\t1',
#  'ESP079\t1',
#  'ESP081\t0',
#  'ESP082\t1',
#  'ESP083\t1',
#  'ESP084\t1',
#  'ESP088\t1',
#  'ESP091\t0',
#  'F1659\t0',
#  'F1688\t0',
#  'F1689\t0',
#  'F1697\t1',
#  'F1706\t0',
#  'F1712\t1',
#  'F1724\t1',
#  'F1727\t0',
#  'F1741\t1',
#  'F1745\t1',
#  'F1746\t1',
#  'F1747\t1',
#  'F1748\t0',
#  'F1752\t1',
#  'F1754\t1',
#  'F1757\t0',
#  'F1758\t0',
#  'F1759\t0',
#  'F1760\t1',
#  'F1763\t1',
#  'F1764\t0',
#  'F1775\t0',
#  'F1787\t1',
#  'F1789\t1',
#  'F1795\t1',
#  'F1796\t1',
#  'F1798\t1',
#  'F1800\t0',
#  'F1801\t0',
#  'F1810\t1',
#  'F1812\t1',
#  'F1821\t1',
#  'F1823\t0',
#  'F1853\t1',
#  'F1862\t0',
#  'F1864\t1',
#  'F1869\t1',
#  'F1880\t0',
#  'F1883\t0',
#  'F1894\t0',
#  'F1957\t0',
#  'F1968\t0',
#  'F1979\t1',
#  'F1983\t1',
#  'F1997\t0',
#  'F2000\t1',
#  'F2003\t0',
#  'F2005\t0',
#  'F2006\t0',
#  'F2010\t0',
#  'F2017\t0',
#  'F2020\t0',
#  'F2029\t0',
#  'F2030\t1',
#  'F2034\t0',
#  'F2035\t0',
#  'F2040\t1',
#  'F2044\t0',
#  'F2045\t1',
#  'F2054\t1',
#  'F2055\t1',
#  'F2056\t1',
#  'F2059\t1',
#  'F2064\t1',
#  'F2065\t0',
#  'F2073\t1',
#  'F2075\t0',
#  'F2081\t0',
#  'F2084\t0',
#  'F2093\t0',
#  'F2097\t1',
#  'F2098\t1',
#  'F2128\t0',
#  'F2137\t0',
#  'F2148\t0',
#  'F2165\t0',
#  'F2166\t0',
#  'F2167\t1',
#  'F2172\t0',
#  'F2176\t1',
#  'F2199\t1',
#  'F2205\t0',
#  'F2208\t1',
#  'F2230\t0',
#  'F2234\t0',
#  'F2235\t1',
#  'F2236\t0',
#  'F2240\t1',
#  'M70563004\t0',
#  'M70564993\t0',
#  'M70565254\t0',
#  'M70565897\t0',
#  'M70604538\t0',
#  'M70608424\t0',
#  'M70635118\t1',
#  'M70638412\t1',
#  'M70639645\t0',
#  'M70640096\t0',
#  'M70641593\t0',
#  'M70646050\t0',
#  'M70646077\t0',
#  'M70647319\t0',
#  'M70649365\t0',
#  'M70652746\t0',
#  'M70656672\t0',
#  'M70663247\t0',
#  'MHH0147\t0',
#  'MHH0426\t0',
#  'MHH0927\t0',
#  'MHH14911\t0',
#  'MHH14929\t0',
#  'MHH14990\t0',
#  'MHH15015\t0',
#  'MHH15083\t1',
#  'MHH15103\t0',
#  'MHH15151\t0',
#  'MHH15187\t0',
#  'MHH15204\t0',
#  'MHH1525\t1',
#  'MHH15275\t1',
#  'MHH15280\t0',
#  'MHH15817\t0',
#  'MHH16050\t0',
#  'MHH16208\t0',
#  'MHH16371\t0',
#  'MHH16379\t0',
#  'MHH16427\t0',
#  'MHH16459\t0',
#  'MHH16513\t0',
#  'MHH16530\t0',
#  'MHH16563\t0',
#  'MHH16610\t0',
#  'MHH16727\t0',
#  'MHH16798\t0',
#  'MHH17233\t1',
#  'MHH17247\t0',
#  'MHH17441\t1',
#  'MHH17501\t0',
#  'MHH17546\t1',
#  'MHH17767\t1',
#  'MHH17783\t0',
#  'MHH1883\t0',
#  'MHH2419\t0',
#  'MS1\t0',
#  'MS2\t0',
#  'MS5\t0',
#  'PSAE1401\t0',
#  'PSAE1438\t0',
#  'PSAE1439\t0',
#  'PSAE1630\t0',
#  'PSAE1635\t0',
#  'PSAE1641\t0',
#  'PSAE1642\t0',
#  'PSAE1645\t0',
#  'PSAE1647\t0',
#  'PSAE1649\t0',
#  'PSAE1651\t0',
#  'PSAE1654\t0',
#  'PSAE1656\t0',
#  'PSAE1742\t0',
#  'PSAE1745\t1',
#  'PSAE1837\t0',
#  'PSAE1872\t0',
#  'PSAE1903\t0',
#  'PSAE1912\t0',
#  'PSAE1934\t0',
#  'PSAE1970\t0',
#  'PSAE1975\t0',
#  'PSAE1984\t0',
#  'PSAE2125\t0',
#  'PSAE2126\t0',
#  'PSAE2127\t1',
#  'PSAE2139\t1',
#  'PSAE2325\t0',
#  'Vb20477\t1',
#  'Vb3320\t0',
#  'ZG02420619\t0',
#  'ZG02488718\t0',
#  'ZG02512057\t0',
#  'ZG205565\t0',
#  'ZG205694\t0',
#  'ZG205710\t0',
#  'ZG205864\t1',
#  'ZG301975\t0',
#  'ZG302359\t0',
#  'ZG302367\t0',
#  'ZG302368\t0',
#  'ZG302370\t0',
#  'ZG302383\t0',
#  'ZG302431\t0',
#  'ZG302432\t0',
#  'ZG302442\t0',
#  'ZG302451\t0',
#  'ZG314696\t0',
#  'ZG314738\t0',
#  'ZG314777\t0',
#  'ZG316694\t0',
#  'ZG316704\t0',
#  'ZG316716\t0',
#  'ZG316722\t0',
#  'ZG322541\t1',
#  'ZG5003493\t0',
#  'ZG5021922\t1',
#  'ZG5048010\t1',
#  'ZG5051896\t1',
#  'ZG5089456\t1',
#  'ZG8006959\t1',
#  'ZG8038581181\t1',
#  'ZG8510487\t1',
#  'ZG8525123\t1']

# %%
import sys
sys.path.append('../')
from utility.file_utility import FileUtility

# %%
SWISS_seqs=FileUtility.read_fasta_sequences('/mounts/data/proj/asgari/final_proj/bioelmo/uniref-uniprot%3A%28reviewed%3Ayes%29+identity%3A0.5.fasta')

# %%
import numpy as np
from sklearn.model_selection import train_test_split

# %%
X_train, X_test = train_test_split(SWISS_seqs,test_size=0.1, random_state=42)

# %%
FileUtility.save_list('/mounts/data/proj/asgari/final_proj/000_datasets/prot/uniref_swissprot/train.txt',[' '.join(list(x.lower())) for x in X_train])

# %%
FileUtility.save_list('/mounts/data/proj/asgari/final_proj/000_datasets/prot/uniref_swissprot/test.txt',[' '.join(list(x.lower())) for x in X_test])
